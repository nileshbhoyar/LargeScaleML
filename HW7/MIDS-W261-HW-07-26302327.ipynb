# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#-MIDS---w261-Machine-Learning-At-Scale-" data-toc-modified-id="-MIDS---w261-Machine-Learning-At-Scale--1"><span class="toc-item-num">1&nbsp;&nbsp;</span> MIDS - w261 Machine Learning At Scale </a></div><div class="lev2 toc-item"><a href="#Assignment---HW7" data-toc-modified-id="Assignment---HW7-11"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Assignment - HW7</a></div><div class="lev1 toc-item"><a href="#Instructions" data-toc-modified-id="Instructions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Instructions</a></div><div class="lev2 toc-item"><a href="#IMPORTANT" data-toc-modified-id="IMPORTANT-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>IMPORTANT</a></div><div class="lev3 toc-item"><a href="#===-INSTRUCTIONS-for-SUBMISSIONS-===" data-toc-modified-id="===-INSTRUCTIONS-for-SUBMISSIONS-===-211"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>=== INSTRUCTIONS for SUBMISSIONS ===</a></div><div class="lev1 toc-item"><a href="#General-Description" data-toc-modified-id="General-Description-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>General Description</a></div><div class="lev3 toc-item"><a href="#Undirected-toy-network-dataset" data-toc-modified-id="Undirected-toy-network-dataset-301"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Undirected toy network dataset</a></div><div class="lev3 toc-item"><a href="#Directed-toy-network-dataset" data-toc-modified-id="Directed-toy-network-dataset-302"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>Directed toy network dataset</a></div><div class="lev1 toc-item"><a href="#HW-7.0:-Shortest-path-graph-distances-(toy-networks)" data-toc-modified-id="HW-7.0:-Shortest-path-graph-distances-(toy-networks)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>HW 7.0: Shortest path graph distances (toy networks)</a></div><div class="lev3 toc-item"><a href="#Main-dataset-1:-NLTK-synonyms" data-toc-modified-id="Main-dataset-1:-NLTK-synonyms-401"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>Main dataset 1: NLTK synonyms</a></div><div class="lev1 toc-item"><a href="#HW-7.1:-Exploratory-data-analysis-(NLTK-synonyms)" data-toc-modified-id="HW-7.1:-Exploratory-data-analysis-(NLTK-synonyms)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>HW 7.1: Exploratory data analysis (NLTK synonyms)</a></div><div class="lev1 toc-item"><a href="#HW-7.2:-Shortest-path-graph-distances-(NLTK-synonyms)" data-toc-modified-id="HW-7.2:-Shortest-path-graph-distances-(NLTK-synonyms)-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>HW 7.2: Shortest path graph distances (NLTK synonyms)</a></div><div class="lev1 toc-item"><a href="#HW-7.3:-Exploratory-data-analysis-(Wikipedia)" data-toc-modified-id="HW-7.3:-Exploratory-data-analysis-(Wikipedia)-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>HW 7.3: Exploratory data analysis (Wikipedia)</a></div><div class="lev1 toc-item"><a href="#HW-7.4:-Shortest-path-graph-distances-(Wikipedia)" data-toc-modified-id="HW-7.4:-Shortest-path-graph-distances-(Wikipedia)-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>HW 7.4: Shortest path graph distances (Wikipedia)</a></div><div class="lev1 toc-item"><a href="#HW-7.5:-Conceptual-exercise:-Largest-single-source-network-distances" data-toc-modified-id="HW-7.5:-Conceptual-exercise:-Largest-single-source-network-distances-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>HW 7.5: Conceptual exercise: Largest single-source network distances</a></div><div class="lev1 toc-item"><a href="#HW-7.5.1:-" data-toc-modified-id="HW-7.5.1:--10"><span class="toc-item-num">10&nbsp;&nbsp;</span>HW 7.5.1: </a></div><div class="lev1 toc-item"><a href="#HW-7.5.2:-Combiners:-OPTIONAL-" data-toc-modified-id="HW-7.5.2:-Combiners:-OPTIONAL--11"><span class="toc-item-num">11&nbsp;&nbsp;</span>HW 7.5.2: Combiners: OPTIONAL </a></div><div class="lev1 toc-item"><a href="#HW-7.6:-Computational-exercise:-Largest-single-source-network-distances:-OPTIONAL-" data-toc-modified-id="HW-7.6:-Computational-exercise:-Largest-single-source-network-distances:-OPTIONAL--12"><span class="toc-item-num">12&nbsp;&nbsp;</span>HW 7.6: Computational exercise: Largest single-source network distances: OPTIONAL </a></div><div class="lev1 toc-item"><a href="#HW-7.7:-Bellman–Ford:-OPTIONAL-" data-toc-modified-id="HW-7.7:-Bellman–Ford:-OPTIONAL--13"><span class="toc-item-num">13&nbsp;&nbsp;</span>HW 7.7: Bellman–Ford: OPTIONAL </a></div>

# %% [markdown]
# <h1> MIDS - w261 Machine Learning At Scale </h1>
# __Course Lead:__ Dr James G. Shanahan (__email__ Jimi via  James.Shanahan _AT_ gmail.com)
#
# <h2>Assignment - HW7</h2>
#
#
# ---
# __Name:__  *Your Name Goes Here*
# __Class:__ MIDS w261 (Section *Your Section Goes Here*, e.g., Fall 2016 Group 1)
# __Email:__  nilesh.bhoyar@iSchool.Berkeley.edu
# __StudentId__  26302327    __End of StudentId__
# __Week:__   7
#
# __NOTE:__ please replace `1234567` with your student id above
# __Due Time:__ HW is due the Tuesday of the following week by 8AM (West coast time). I.e., Tuesday, Mar 14, 2017 in the case of this homework.
#
# # Instructions
#
# MIDS UC Berkeley, Machine Learning at Scale
# DATSCIW261 ASSIGNMENT #7
#
# Version 2017-3-9
#
#
# ## IMPORTANT
#
# This homework can be completed locally on your computer
#
# ### === INSTRUCTIONS for SUBMISSIONS ===
# Follow the instructions for submissions carefully.
#
# Each student has a `HW-<user>` repository for all assignments.
#
# Click this link to enable you to create a github repo within the MIDS261 Classroom:
# https://classroom.github.com/assignment-invitations/3b1d6c8e58351209f9dd865537111ff8
# and follow the instructions to create a HW repo.
#
# Push the following to your HW github repo into the master branch:
# * Your local HW6 directory. Your repo file structure should look like this:
#
# ```
# HW-<user>
#     --HW3
#        |__MIDS-W261-HW-03-<Student_id>.ipynb
#        |__MIDS-W261-HW-03-<Student_id>.pdf
#        |__some other hw3 file
#     --HW4
#        |__MIDS-W261-HW-04-<Student_id>.ipynb
#        |__MIDS-W261-HW-04-<Student_id>.pdf
#        |__some other hw4 file
#     etc..
# ```

# %% [markdown]
# <h1 style="color:#021353;">General Description</h1>
# <div style="margin:10px;border-left:5px solid #eee;">
# <pre style="font-family:sans-serif;background-color:transparent">
# In this assignment you will explore networks and develop MRJob code for
# finding shortest path graph distances. To build up to large data
# you will develop your code on some very simple, toy networks.
# After this you will take your developed code forward and modify it and
# apply it to two larger datasets (performing EDA along the way).
#
# <h3>Undirected toy network dataset</h3>
#
#
# In an undirected network all links are symmetric,
# i.e., for a pair of nodes 'A' and 'B,' both of the links:
#
# A -> B and B -> A
#
# will exist.
#
# The toy data are available in a sparse (stripes) representation:
#
# (node) \t (dictionary of links)
#
# on AWS/Dropbox via the url:
#
# s3://ucb-mids-mls-networks/undirected_toy.txt
# On under the Data Subfolder for HW7 on Dropbox with the same file name.
# The Data folder is in: https://db.tt/Kxu48mL1)
#
# In the dictionary, target nodes are keys, link weights are values
# (here, all weights are 1, i.e., the network is unweighted).
#
#
# <h3>Directed toy network dataset</h3>
#
# In a directed network all links are not necessarily symmetric,
# i.e., for a pair of nodes 'A' and 'B,' it is possible for only one of:
#
# A -> B or B -> A
#
# to exist.
#
# These toy data are available in a sparse (stripes) representation:
#
# (node) \t (dictionary of links)
#
# on AWS/Dropbox via the url:
#
# s3://ucb-mids-mls-networks/directed_toy.txt
# Or under the Data Subfolder for HW7 on Dropbox with the same file name
# (On Dropbox https://www.dropbox.com/sh/2c0k5adwz36lkcw/AAAAKsjQfF9uHfv-X9mCqr9wa?dl=0)
#
# In the dictionary, target nodes are keys, link weights are values
# (here, all weights are 1, i.e., the network is unweighted).
# </pre>
# </div>

# %% [markdown]
# <h1 style="color:#021353;">HW 7.0: Shortest path graph distances (toy networks)</h1>
# <div style="margin:10px;border-left:5px solid #eee;">
# <pre style="font-family:sans-serif;background-color:transparent">
# In this part of your assignment you will develop the base of your code for the week.
#
# Write MRJob classes to find shortest path graph distances, as described in the lectures. In addition to finding the distances, your code should also output a distance-minimizing path between the source and target.
# Work locally for this part of the assignment, and use both of the undirected and directed toy networks.
#
# To proof you code's function, run the following jobs
#
# - shortest path in the undirected network from node 1 to node 4
# Solution: 1,5,4. NOTE: There is another shortest path also (HINT: 1->5->4)! Either will suffice (you will find this also in the remaining problems. E.g., 7.2 and 7.4.
#
#
# - shortest path in the directed network from node 1 to node 5
# Solution: 1,2,4,5
#
# and report your output---make sure it is correct!
#
# <h3>Main dataset 1: NLTK synonyms</h3>
#
# In the next part of this assignment you will explore a network derived from the NLTK synonym database used for evaluation in HW 5. At a high level, this network is undirected, defined so that there exists link between two nodes/words if the pair or words are a synonym. These data may be found at the location:
#
# <a href="s3://ucb-mids-mls-networks/synNet/synNet.txt">s3://ucb-mids-mls-networks/synNet/synNet.txt</a>
# <a href="s3://ucb-mids-mls-networks/synNet/indices.txt">s3://ucb-mids-mls-networks/synNet/indices.txt</a>
# On under the Data Subfolder for HW7 on Dropbox with the same file names
#
# where synNet.txt contains a sparse representation of the network:
#
# (index) \t (dictionary of links)
#
# in indexed form, and indices.txt contains a lookup list
#
# (word) \t (index)
#
# of indices and words. This network is small enough for you to explore and run
# scripts locally, but will also be good for a systems test (for later) on AWS.
#
# In the dictionary, target nodes are keys, link weights are values
# (here, all weights are 1, i.e., the network is unweighted).
# </pre>
# </div>

# %%
# %%writefile directed_toy_graph.txt
# 1	{'2': 1, '6': 1}
# 2	{'1': 1, '3': 1, '4': 1}
# 3	{'2': 1, '4': 1}
# 4	{'2': 1, '5': 1}
# 5	{'1': 1, '2': 1, '4': 1}
# Out:
# Overwriting directed_toy_graph.txt

# %%
# %%writefile undirected_toy_graph.txt
# 1	{'2': 1,'5': 1}
# 2	{'1': 1,'3': 1,'4': 1,'5': 1}
# 3	{'2': 1, '4': 1}
# 4	{'2': 1,'3': 1,'5': 1}
# 5	{'1': 1, '2': 1, '4': 1}
# Out:
# Overwriting undirected_toy_graph.txt

# %%
# %%writefile undirected_weighted_toy_graph.txt
# 1	{"2": 1, "5": 100}
# 2	{"1": 1, "3": 1, "5": 1, "4": 1}
# 3	{"2": 1, "4": 1}
# 4	{"3": 1, "2": 1, "5": 1}
# 5	{"1": 100, "2": 1, "4": 1, "6":1}
# 6	{"5": 1, "7": 1}
# 7	{"6": 1}
# Out:
# Overwriting undirected_weighted_toy_graph.txt

# %%
# !cat directed_toy_graph.txt
print "\n","-"*100
# !cat undirected_toy_graph.txt
print "\n","-"*100
# !cat undirected_weighted_toy_graph.txt
# Out:
# 1	{'2': 1, '6': 1}
# 2	{'1': 1, '3': 1, '4': 1}
# 3	{'2': 1, '4': 1}
# 4	{'2': 1, '5': 1}
# 5	{'1': 1, '2': 1, '4': 1}
# ----------------------------------------------------------------------------------------------------
# 1	{'2': 1,'5': 1}
# 2	{'1': 1,'3': 1,'4': 1,'5': 1}
# 3	{'2': 1, '4': 1}
# 4	{'2': 1,'3': 1,'5': 1}
# 5	{'1': 1, '2': 1, '4': 1}
# ----------------------------------------------------------------------------------------------------
# 1	{"2": 1, "5": 100}
# 2	{"1": 1, "3": 1, "5": 1, "4": 1}
# 3	{"2": 1, "4": 1}
# 4	{"3": 1, "2": 1, "5": 1}
# 5	{"1": 100, "2": 1, "4": 1, "6":1}
# 6	{"5": 1, "7": 1}
# 7	{"6": 1}

# %% [markdown]
# <img src="http://www.candpgeneration.com/images/graphs.png" style="float:left;"/>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%writefile sssp_init.py 
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

# START STUDENT CODE 7.0
# (ADD CELLS AS NEEDED)


from __future__ import division 
import re
import random
import sys
import mrjob
from mrjob.job import MRJob 
from mrjob.step import MRStep
from mrjob.protocol import RawValueProtocol

class MRSSSP_INIT(MRJob):
   
    
    def configure_options(self):
        super(MRSSSP_INIT, self).configure_options()
        self.add_passthrough_option('--firstnode', default='1')

    def mapper(self, _, line):
         fields = line.strip().split('\t')
         name = fields[0]
         neighbors = eval(fields[1])
         if name == self.options.firstnode:
            yield name, [neighbors, 0, 'Q']
         else:
            yield name, [neighbors, sys.maxint, 'U']    
    def steps(self): 
       
        return [MRStep( mapper=self.mapper)
               ]
   
if __name__ == '__main__' and sys.argv[0].find('ipykernel') == -1:
    MRSSSP_INIT().run()
# END STUDENT CODE 7.0
# Out:
# Overwriting sssp_init.py

# %%
# %%writefile sssp.py 
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

# START STUDENT CODE 7.0
# (ADD CELLS AS NEEDED)


from __future__ import division 
import re
import random
import sys
import mrjob
from mrjob.job import MRJob 
from mrjob.step import MRStep
from mrjob.protocol import RawValueProtocol

class MRSSSP(MRJob):
   
    def mapper(self, _, line):
         fields = line.strip().split('\t')
         name = str(eval(fields[0]))
         value = eval(fields[1])
         neighbors = value[0]
         distance = int(value[1])
         status = value[2]
         path= []
         if len(value) > 3:
             path = value[3]


         if status == 'Q':
                     
            self.increment_counter('group', 'QQ_counter', 1)
            yield name, [neighbors, distance, 'V', path]
            if neighbors:
                for node in neighbors:
                    temp_path = list(path)
                    temp_path.append(node)
                  
                    yield str(node), [None, distance + int(neighbors[node]) , 'Q',temp_path]
         else:
            yield name, [neighbors, distance, status,path]
    
    def reducer(self, key, values):
        neighbors = {}
        distance = sys.maxint
        status = None
        path = []

      
        for val in values:

            #if already visited nothing to do than pass through
            if val[2] == 'V':
                neighbors = val[0]
                distance = val[1]
                status = val[2]
                path = val[3]
                break

#for frontiers we just need to find all neighbours and update the distance from mapper entry
            elif val[0]:
                neighbors = val[0]
                if status != 'Q':
                    status = val[2]

            else:
                status = val[2]
                path = val[3]
  
            # Update minimum distance if necessary
            distance = min(distance, val[1])

        yield key, [neighbors, distance, status,path]
        
    def steps(self): 
       
        return [MRStep( 
                        mapper=self.mapper,
                        reducer=self.reducer,
                        jobconf = {
                        'mapred.map.tasks': 100,
                        'mapred.reduce.tasks':20,
                        'mapreduce.reduce.cpu.vcores':4,
                        })
               ]
   
if __name__ == '__main__' and sys.argv[0].find('ipykernel') == -1:
    MRSSSP.run()
# END STUDENT CODE 7.0
# Out:
# Overwriting sssp.py

# %%
# !python sssp_init.py -r local 'directed_toy_graph.txt' > directed_toy_adjlist.txt
# Out:
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/sssp_init.nileshbhoyar.20170709.155353.877317
# Running step 1 of 1...
# Streaming final output from /tmp/sssp_init.nileshbhoyar.20170709.155353.877317/output...
# Removing temp directory /tmp/sssp_init.nileshbhoyar.20170709.155353.877317...

# %%
from sssp import MRSSSP
filenameState='directed_toy_adjlist.txt'
filenameTemp = filenameState + '.tmp'

for i in range(10):
    notexit = None
    with open(filenameTemp, 'w') as myfile:
         with mr_job.make_runner() as runner:
                # Run MRJob
                runner.run()
                 
                # Write stream_output to file
                for line in runner.stream_output():
                    out = mr_job.parse_output_line(line)
                    value = out[1]
                    
                    if  value[2] == 'Q':
                        notexit = 'X'
                    myfile.write(str(out[0]) + '\t' + str(out[1]) + '\n')
                    if out[0] == '5' and out[1][2] == 'V':
                        path = out[1][3]
                        print path ,'and distance',out[1][1]
    #if len(runner.counters()) == 0:
                    #break
    # !echo "**********Iteration {i}**************"
    #!cat {filenameTemp  }           
    # !mv {filenameTemp} {filenameState}
    #if notexit == None:
    #    break
    if len(runner.counters()[0]) == 0:
        break
# Out:
# **********Iteration 0**************
# **********Iteration 1**************
# **********Iteration 2**************
# [u'2', u'4', u'5'] and distance 3
# **********Iteration 3**************
# [u'2', u'4', u'5'] and distance 3
# **********Iteration 4**************

# %%
from sssp import MRSSSP
filenameState='directed_toy_adjlist.txt'
filenameTemp = filenameState + '.tmp'
mr_job = MRSSSP(args=[
        filenameState,
        '--no-strict-protocols'
    ])
notexit =None
for i in range(10):
    notexit = None
    with open(filenameTemp, 'w') as myfile:
         with mr_job.make_runner() as runner:
                # Run MRJob
                runner.run()
                 
                # Write stream_output to file
                for line in runner.stream_output():
                    out = mr_job.parse_output_line(line)
                    value = out[1]
                    
                    if  value[2] == 'Q':
                        notexit = 'X'
                    myfile.write(str(out[0]) + '\t' + str(out[1]) + '\n')
                    if out[0] == '5' and out[1][2] == 'V':
                        path = out[1][3]
                        print path ,'and distance',out[1][1]
    #!echo "**********Iteration {i}**************"
    #!cat {filenameTemp  }           
    # !mv {filenameTemp} {filenameState}
    if notexit == None:
        break

# %%
# !python sssp_init.py -r local 'undirected_toy_graph.txt' > undirected_toy_adjlist.txt
# Out:
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/sssp_init.nileshbhoyar.20170709.103031.368830
# Running step 1 of 1...
# Streaming final output from /tmp/sssp_init.nileshbhoyar.20170709.103031.368830/output...
# Removing temp directory /tmp/sssp_init.nileshbhoyar.20170709.103031.368830...

# %%
from sssp import MRSSSP
filenameState='undirected_toy_adjlist.txt'
filenameTemp = filenameState + '.tmp'
mr_job = MRSSSP(args=[
        filenameState,
        '--no-strict-protocols'
    ])
notexit =None
for i in range(10):
    notexit = None
    with open(filenameTemp, 'w') as myfile:
         with mr_job.make_runner() as runner:
                # Run MRJob
                runner.run()

                # Write stream_output to file
                for line in runner.stream_output():
                    out = mr_job.parse_output_line(line)
                    value = out[1]
                    
                    if value[2] == 'U' or value[2] == 'Q':
                        notexit = 'X'
                    myfile.write(str(out[0]) + '\t' + str(out[1]) + '\n')
                    if out[0] == '4' and out[1][2] == 'V':
                        path = out[1][3]
                        print path ,'and distance',out[1][1]
                        
    #!echo "**********Iteration {i}**************"
    #!cat {filenameTemp  }           
                
    # !mv {filenameTemp} {filenameState}
    if notexit == None:
        break
# Out:
# [u'5', u'4'] and distance 2

# %%
# !python sssp_init.py -r local 'undirected_weighted_toy_graph.txt' > undirected_weighted_toyadjlist.txt
# Out:
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/sssp_init.nileshbhoyar.20170709.103032.690479
# Running step 1 of 1...
# Streaming final output from /tmp/sssp_init.nileshbhoyar.20170709.103032.690479/output...
# Removing temp directory /tmp/sssp_init.nileshbhoyar.20170709.103032.690479...

# %%
from sssp import MRSSSP
filenameState='undirected_weighted_toyadjlist.txt'
filenameTemp = filenameState + '.tmp'
mr_job = MRSSSP(args=[
        filenameState,
        '--no-strict-protocols'
    ])
notexit =None
for i in range(10):
    notexit = None
    with open(filenameTemp, 'w') as myfile:
         with mr_job.make_runner() as runner:
                # Run MRJob
                runner.run()

                # Write stream_output to file
                for line in runner.stream_output():
                    out = mr_job.parse_output_line(line)
                    value = out[1]
                    
                    if value[2] == 'U' or value[2] == 'Q':
                        notexit = 'X'
                    myfile.write(str(out[0]) + '\t' + str(out[1]) + '\n')
                    if out[0] == '4' and out[1][2] == 'V':
                        path = out[1][3]
                        print path ,'and distance',out[1][1]
                 
    #!echo "**********Iteration {i}**************"
    #!cat {filenameTemp  }           
   
    # !mv {filenameTemp} {filenameState}
    if notexit == None:
        break
# Out:
# [u'2', u'4'] and distance 2
# [u'2', u'4'] and distance 2

# %% [markdown]
# <h1 style="color:#021353;">HW 7.1: Exploratory data analysis (NLTK synonyms)</h1>
# <div style="margin:10px;border-left:5px solid #eee;">
# <pre style="font-family:sans-serif;background-color:transparent">
# Using MRJob, explore the synonyms network data.
# Consider plotting the degree distribution (does it follow a power law?),
# and determine some of the key features, like:
#
# number of nodes,
# number links,
# or the average degree (i.e., the average number of links per node),
# etc...
#
# As you develop your code, please be sure to run it locally first (though on the whole dataset).
# Once you have gotten you code to run locally, deploy it on AWS as a systems test
# in preparation for our next dataset (which will require AWS).
# </pre>
# </div>

# %%
# !rm synNet.txt
# !rm indices.txt
# !wget https://www.dropbox.com/sh/2c0k5adwz36lkcw/AABC3Ddz83xM3yURo3S89yGaa/synNet/synNet.txt
# !wget https://www.dropbox.com/sh/2c0k5adwz36lkcw/AADyOueLkWD9r6251y4JDI1Ka/synNet/indices.txt
# Out:
# --2017-07-09 10:30:34--  https://www.dropbox.com/sh/2c0k5adwz36lkcw/AABC3Ddz83xM3yURo3S89yGaa/synNet/synNet.txt
# Resolving www.dropbox.com... 162.125.6.1
# Connecting to www.dropbox.com|162.125.6.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl.dropboxusercontent.com/content_link/xf5W8dq17rSTdKIeQxZwXBm54EiLY4WYdlfnjN31YZz1vCyrkkbj5W8WpjMV7roD/file [following]
# --2017-07-09 10:30:35--  https://dl.dropboxusercontent.com/content_link/xf5W8dq17rSTdKIeQxZwXBm54EiLY4WYdlfnjN31YZz1vCyrkkbj5W8WpjMV7roD/file
# Resolving dl.dropboxusercontent.com... 162.125.17.6
# Connecting to dl.dropboxusercontent.com|162.125.17.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 705298 (689K) [text/plain]
# Saving to: `synNet.txt'
#
# 100%[======================================>] 705,298     2.25M/s   in 0.3s
#
# 2017-07-09 10:30:36 (2.25 MB/s) - `synNet.txt' saved [705298/705298]
#
# --2017-07-09 10:30:36--  https://www.dropbox.com/sh/2c0k5adwz36lkcw/AADyOueLkWD9r6251y4JDI1Ka/synNet/indices.txt
# Resolving www.dropbox.com... 162.125.6.1
# Connecting to www.dropbox.com|162.125.6.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl.dropboxusercontent.com/content_link/fkt7oerWEvBDfIatzbf5hqmCDJM7uuSPzgpDn8yPbzbU5YV1YLFGFAlMiU9c4gQV/file [following]
# --2017-07-09 10:30:37--  https://dl.dropboxusercontent.com/content_link/fkt7oerWEvBDfIatzbf5hqmCDJM7uuSPzgpDn8yPbzbU5YV1YLFGFAlMiU9c4gQV/file
# Resolving dl.dropboxusercontent.com... 162.125.17.6
# Connecting to dl.dropboxusercontent.com|162.125.17.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 106891 (104K) [text/plain]
# Saving to: `indices.txt'
#
# 100%[======================================>] 106,891     --.-K/s   in 0.1s
#
# 2017-07-09 10:30:38 (702 KB/s) - `indices.txt' saved [106891/106891]

# %%
# %%writefile eda.py 
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

# START STUDENT CODE 7.1
# (ADD CELLS AS NEEDED)


from __future__ import division 
import re
import random
import sys
import mrjob
from mrjob.job import MRJob 
from mrjob.step import MRStep
from mrjob.protocol import RawValueProtocol

class EDA(MRJob):
    def configure_options(self):
        super(EDA, self).configure_options()
        self.add_passthrough_option('--runtype', default='countnodes')

    def mapper_nodes(self, _, line):
         fields = line.strip().split('\t')
         name = str(eval(fields[0]))
         
         value = eval(fields[1])
         yield name,1
         for node in value:
               yield node,1
                
    def reducer_nodes(self, key, values):
        
         yield key,1
    def mapper_find_sum(self,key,value):
        yield None,1
    def reducer_find_sum(self, key, values):
        yield None, sum(values)
        
    def mapper_links(self, _, line):
         fields = line.strip().split('\t')
         name = str(eval(fields[0]))
         value = eval(fields[1])
        
         degree = len(value)
         yield degree, 1

    def reducer_links(self, degree, frequency):
        yield degree, sum(frequency)
    def mapssum_links(self, _, line):
         fields = line.strip().split('\t')
         name = str(eval(fields[0]))
         value = eval(fields[1])
        
         degree = len(value)
         yield None,degree

    def mapsumreducer_links(self, degree, frequency):
        yield None, sum(frequency)    
    def steps(self): 
       
         if self.options.runtype == 'countnodes':
            return [
                MRStep(mapper=self.mapper_nodes,
                       combiner=self.reducer_nodes,
                       reducer=self.reducer_nodes),
                MRStep(mapper=self.mapper_find_sum,
                       reducer=self.reducer_find_sum)
                
            ]
         elif self.options.runtype == 'countlinks':
            return [
                MRStep(mapper=self.mapper_links,
                       combiner=self.reducer_links,
                       reducer=self.reducer_links)
            ]
         elif self.options.runtype == 'sumlinks':
            return [
                MRStep(mapper=self.mapssum_links,
                       combiner=self.mapsumreducer_links,
                       reducer=self.mapsumreducer_links)
            ]
   
if __name__ == '__main__' and sys.argv[0].find('ipykernel') == -1:
    EDA.run()
# END STUDENT CODE 7.1
# Out:
# Overwriting eda.py

# %% [markdown]
# ## No of Nodes

# %%
# !python eda.py -r local --runtype countnodes 'synNet.txt' |cut -f 2
# Out:
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/eda.nileshbhoyar.20170709.103038.332461
# Running step 1 of 2...
# Running step 2 of 2...
# Streaming final output from /tmp/eda.nileshbhoyar.20170709.103038.332461/output...
# Removing temp directory /tmp/eda.nileshbhoyar.20170709.103038.332461...
# 8271

# %% [markdown]
# ## Frequencies for plotting histogram

# %%
# !python eda.py -r local --runtype countlinks 'synNet.txt' >linksfrequency.txt
# Out:
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/eda.nileshbhoyar.20170709.103040.700142
# Running step 1 of 1...
# Streaming final output from /tmp/eda.nileshbhoyar.20170709.103040.700142/output...
# Removing temp directory /tmp/eda.nileshbhoyar.20170709.103040.700142...

# %% [markdown]
# ## Total links

# %%
# !python eda.py -r local --runtype sumlinks 'synNet.txt' | cut -f 2
# Out:
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/eda.nileshbhoyar.20170709.103042.132525
# Running step 1 of 1...
# Streaming final output from /tmp/eda.nileshbhoyar.20170709.103042.132525/output...
# Removing temp directory /tmp/eda.nileshbhoyar.20170709.103042.132525...
# 61134

# %% [markdown]
# ## Average links
#
#     = 61134/8271
#     = 7.391367428364164

# %%
# %matplotlib inline
import numpy as np
import seaborn as sns
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
data =  np.loadtxt('linksfrequency.txt')
bins, weights = data.astype(int).T
plt.hist(bins, 20, weights = weights)
# Out:
# (array([  6.65000000e+03,   1.05700000e+03,   3.08000000e+02,
#           1.18000000e+02,   6.20000000e+01,   4.00000000e+01,
#           1.60000000e+01,   5.00000000e+00,   3.00000000e+00,
#           3.00000000e+00,   0.00000000e+00,   3.00000000e+00,
#           1.00000000e+00,   1.00000000e+00,   2.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00]),
#  array([   1.  ,   10.75,   20.5 ,   30.25,   40.  ,   49.75,   59.5 ,
#           69.25,   79.  ,   88.75,   98.5 ,  108.25,  118.  ,  127.75,
#          137.5 ,  147.25,  157.  ,  166.75,  176.5 ,  186.25,  196.  ]),
#  <a list of 20 Patch objects>)
# /home/nileshbhoyar/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## CDF

# %%
# Use the histogram function to bin the data
new_bins = np.linspace(min(bins), max(bins), num=100)
counts, bin_edges = np.histogram(weights, bins=new_bins, normed=True)

# Now find the cdf
cdf = np.cumsum(counts)

# And finally plot the cdf
plt.plot(bin_edges[1:], cdf)

plt.show()

# %% [markdown]
# <h1 style="color:#021353;">HW 7.2: Shortest path graph distances (NLTK synonyms)</h1>
# <div style="margin:10px;border-left:5px solid #eee;">
# <pre style="font-family:sans-serif;background-color:transparent">
# Write (reuse your code from 7.0) an MRJob class to find shortest path graph distances,
# and apply it to the NLTK synonyms network dataset.
#
# Proof your code's function by running the job:
#
# - shortest path starting at "walk" (index=7827) and ending at "make" (index=536),
#
# and showing you code's output. Once again, your output should include the path and the distance.
#
# As you develop your code, please be sure to run it locally first (though on the whole dataset).
# Once you have gotten you code to run locally, deploy it on Altiscale as a systems test
# in preparation for our next dataset (which will require Altiscale).
#
# =====================================
# <strong>NOTE: Dataset 2 English Wikipedia hyperlink network.data </strong>
# The dataset is available via Dropbox at:
#
# https://www.dropbox.com/sh/2c0k5adwz36lkcw/AAAAKsjQfF9uHfv-X9mCqr9wa?dl=0
#
# on S3 at
# <a href="s3://ucb-mids-mls-networks/wikipedia/">s3://ucb-mids-mls-networks/wikipedia/</a>
# <a href="s3://ucb-mids-mls-networks/wikipedia/all-pages-indexed-out.txt">s3://ucb-mids-mls-networks/wikipedia/all-pages-indexed-out.txt</a> # Graph
# <a href="s3://ucb-mids-mls-networks/wikipedia/indices.txt">s3://ucb-mids-mls-networks/wikipedia/indices.txt</a> # Page titles and page Ids
#
# To download files using wget use this format:
# `wget http://ucb-mids-mls-networks.s3.amazonaws.com/wikipedia/indices.txt`
#
# If you have AWS CLI installed and configured, you can use:
# `aws s3 cp s3://ucb-mids-mls-networks/wikipedia/indices.txt indices.txt`
#
# For the remainder of this assignment you will explore the English Wikipedia hyperlink network.
#
# The dataset is built from the Sept. 2015 XML snapshot of English Wikipedia.
# For this directed network, a link between articles:
#
# A -> B
#
# is defined by the existence of a hyperlink in A pointing to B.
# This network also exists in the indexed format:
#
# Data: <a href="s3://ucb-mids-mls-networks/wikipedia/all-pages-indexed-out.txt">s3://ucb-mids-mls-networks/wikipedia/all-pages-indexed-out.txt</a>
# Data: <a href="s3://ucb-mids-mls-networks/wikipedia/all-pages-indexed-in.txt">s3://ucb-mids-mls-networks/wikipedia/all-pages-indexed-in.txt</a>
# Data: <a href="s3://ucb-mids-mls-networks/wikipedia/indices.txt">s3://ucb-mids-mls-networks/wikipedia/indices.txt</a>
#
# but has an index with more detailed data:
#
# (article name) \t (index) \t (in degree) \t (out degree)
#
# In the dictionary, target nodes are keys, link weights are values .
# Here, a weight indicates the number of time a page links to another.
# However, for the sake of this assignment, treat this an unweighted network,
# and set all weights to 1 upon data input.
#
# </pre>
# </div>

# %%
# START STUDENT CODE 7.2
# (ADD CELLS AS NEEDED)
# !python sssp_init.py -r local --firstnode 7827 'synNet.txt'> revised_adjlist.txt
# END STUDENT CODE 7.2
# Out:
# No configs found; falling back on auto-configuration
# Creating temp directory /tmp/sssp_init.nileshbhoyar.20170709.155437.249302
# Running step 1 of 1...
# Streaming final output from /tmp/sssp_init.nileshbhoyar.20170709.155437.249302/output...
# Removing temp directory /tmp/sssp_init.nileshbhoyar.20170709.155437.249302...

# %%
from sssp import MRSSSP
filenameState='revised_adjlist.txt'
filenameTemp = filenameState + '.tmp'
mr_job = MRSSSP(args=[
        filenameState,
        '--no-strict-protocols'
    ])
notexit =None
for i in range(10):
    notexit = None
    with open(filenameTemp, 'w') as myfile:
         with mr_job.make_runner() as runner:
                # Run MRJob
                runner.run()

                # Write stream_output to file
                for line in runner.stream_output():
                    out = mr_job.parse_output_line(line)
                    value = out[1]
                    
                    if  value[2] == 'Q':
                        notexit = 'X'
                    myfile.write(str(out[0]) + '\t' + str(out[1]) + '\n')
                    if out[0] == '536' and out[1][2] == 'V':
                        path = out[1][3]
                        print path ,'and distance',out[1][1]
                        
    # !echo "**********Iteration {i}**************"
    #!cat {filenameTemp  }           
    # !mv {filenameTemp} {filenameState}
    #if notexit == None:
    #    break
    if len(runner.counters()[0]) == 0:
        break
print "Actual words in path are:"
reverse_dict = {}
with open('indices.txt', 'r') as f:
        for line in f:
            fields = line.strip().split('\t')
            reverse_dict[fields[1]] = fields[0]
print reverse_dict['7827']
for node in path:
    print reverse_dict[node]
# Out:
# **********Iteration 0**************
# **********Iteration 1**************
# **********Iteration 2**************
# [u'4655', u'631', u'536'] and distance 3
# **********Iteration 3**************
# [u'4655', u'631', u'536'] and distance 3
# **********Iteration 4**************
# [u'4655', u'631', u'536'] and distance 3
# **********Iteration 5**************
# [u'4655', u'631', u'536'] and distance 3
# **********Iteration 6**************
# [u'4655', u'631', u'536'] and distance 3
# **********Iteration 7**************
# [u'4655', u'631', u'536'] and distance 3
# **********Iteration 8**************
# [u'4655', u'631', u'536'] and distance 3
# **********Iteration 9**************
# Actual words in path are:
# walk
# passes
# draw
# make

# %% [markdown]
# <h1 style="color:#021353;">HW 7.3: Exploratory data analysis (Wikipedia)</h1>
# <div style="margin:10px;border-left:5px solid #eee;">
# <pre style="font-family:sans-serif;background-color:transparent">
# Using MRJob, explore the Wikipedia network data on the AWS cloud. Reuse your code from HW 7.1---does is scale well?
#
# Be cautioned that Wikipedia is a directed network, where links are not symmetric.
# So, even though a node may be linked to, it will not appear as a primary record itself if it has no out-links.
#
# This means that you may have to ADJUST your code (depending on its design).
#
# To be sure of your code's functionality in this context, run a systems test on the directed_toy.txt network.
# </pre>
# </div>

# %% [markdown]
# ## System Test in Hadoop Model

# %%
# !hdfs dfs -mkdir hdfs:///user/nileshbhoyar/output/
# !hdfs dfs -rm -r hdfs:///user/nileshbhoyar/output/HW731/
# !python sssp_init.py -r hadoop --output-dir="hdfs:///user/nileshbhoyar/output/HW731/"\
                    --no-output \
                    "hdfs:///user/andrewlam/HW7/directed_toy.txt"
# Out:
# mkdir: `hdfs:/user/nileshbhoyar/output': File exists
# 17/07/09 11:20:12 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 5760 minutes, Emptier interval = 360 minutes.
# Moved: 'hdfs://nn-ia.s3s.altiscale.com:8020/user/nileshbhoyar/output/HW731' to trash at: hdfs://nn-ia.s3s.altiscale.com:8020/user/nileshbhoyar/.Trash/Current
# No configs found; falling back on auto-configuration
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Creating temp directory /tmp/sssp_init.nileshbhoyar.20170709.112013.480501
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/nileshbhoyar/tmp/mrjob/sssp_init.nileshbhoyar.20170709.112013.480501/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob5275419211509474148.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1497906899862_3636
#   Submitted application application_1497906899862_3636
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_3636/
#   Running job: job_1497906899862_3636
#   Job job_1497906899862_3636 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#   Job job_1497906899862_3636 completed successfully
#   Output directory: hdfs:///user/nileshbhoyar/output/HW731/
# Counters: 30
# 	File Input Format Counters
# 		Bytes Read=167
# 	File Output Format Counters
# 		Bytes Written=243
# 	File System Counters
# 		FILE: Number of bytes read=0
# 		FILE: Number of bytes written=263638
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=413
# 		HDFS: Number of bytes written=243
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=10
# 		HDFS: Number of write operations=4
# 	Job Counters
# 		Launched map tasks=2
# 		Rack-local map tasks=2
# 		Total megabyte-milliseconds taken by all map tasks=19980288
# 		Total time spent by all map tasks (ms)=13008
# 		Total time spent by all maps in occupied slots (ms)=39024
# 		Total time spent by all reduces in occupied slots (ms)=0
# 		Total vcore-milliseconds taken by all map tasks=13008
# 	Map-Reduce Framework
# 		CPU time spent (ms)=2220
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=55
# 		Input split bytes=246
# 		Map input records=5
# 		Map output records=5
# 		Merged Map outputs=0
# 		Physical memory (bytes) snapshot=538419200
# 		Spilled Records=0
# 		Total committed heap usage (bytes)=3135242240
# 		Virtual memory (bytes) snapshot=4416684032
# Removing HDFS temp directory hdfs:///user/nileshbhoyar/tmp/mrjob/sssp_init.nileshbhoyar.20170709.112013.480501...
# Removing temp directory /tmp/sssp_init.nileshbhoyar.20170709.112013.480501...

# %%
from sssp import MRSSSP
inputDir='hdfs:///user/nileshbhoyar/output/HW731/'
outputDir = inputDir + 'tmp1'

notexit =None
for i in range(1,10):
    notexit = None
    # !hdfs dfs -rm -r -f -skipTrash outputDir
    mr_job = MRSSSP(args=[
            inputDir,
            '--strict-protocols',
            '-r', 'hadoop',
            '--no-output',
            '--output-dir', outputDir
        ])
    
    with mr_job.make_runner() as runner:
                # Run MRJob
        runner.run()

        for line in runner.stream_output():
                    out = mr_job.parse_output_line(line)
                    value = out[1]
                    
                    if  value[2] == 'Q':
                        notexit = 'X'
                    
                    if out[0] == '5' and out[1][2] == 'V':
                        path = out[1][3]
                        print path ,'and distance',out[1][1]
                        
    # !echo "**********Iteration {i}**************"
    #!cat {filenameTemp  }           
    inputDir = inputDir + 'tmp' + str(i) + '/'
    outputDir = inputDir + 'tmp' + str(i + 1)
    if notexit == None:
        break
# Out:
# **********Iteration 1**************
# **********Iteration 2**************
# **********Iteration 3**************
# [u'2', u'4', u'5'] and distance 3
# **********Iteration 4**************

# %% [markdown]
# ## Now EDA for Wiki Data

# %%
# %%writefile eda.py 
#!~/anaconda2/bin/python
# -*- coding: utf-8 -*-

# START STUDENT CODE 7.1
# (ADD CELLS AS NEEDED)


from __future__ import division 
import re
import random
import sys
import mrjob
from mrjob.job import MRJob 
from mrjob.step import MRStep
from mrjob.protocol import RawValueProtocol

class EDA(MRJob):
    def configure_options(self):
        super(EDA, self).configure_options()
        self.add_passthrough_option('--runtype', default='countnodes')

    def mapper_nodes(self, _, line):
         fields = line.strip().split('\t')
         name = str(eval(fields[0]))
         
         value = eval(fields[1])
         yield name,1
         for node in value:
               yield node,1
                
    def reducer_nodes(self, key, values):
        
         yield key,1
    def mapper_find_sum(self,key,value):
        yield None,1
    def reducer_find_sum(self, key, values):
        yield None, sum(values)
        
    def mapper_links(self, _, line):
         fields = line.strip().split('\t')
         name = str(eval(fields[0]))
         value = eval(fields[1])
        
         degree = len(value)
         yield degree, 1

    def reducer_links(self, degree, frequency):
        yield degree, sum(frequency)
    def mapssum_links(self, _, line):
         fields = line.strip().split('\t')
         name = str(eval(fields[0]))
         value = eval(fields[1])
        
         degree = len(value)
         yield None,degree

    def mapsumreducer_links(self, degree, frequency):
        yield None, sum(frequency)    
    def steps(self): 
       
         if self.options.runtype == 'countnodes':
            return [
                MRStep(mapper=self.mapper_nodes,
                       combiner=self.reducer_nodes,
                       reducer=self.reducer_nodes,
                       jobconf = {
                        'mapred.map.tasks': 500,
                        'mapred.reduce.tasks': 30,
                        'mapreduce.reduce.cpu.vcores':4,
                }
                      ),
                MRStep(mapper=self.mapper_find_sum,
                       reducer=self.reducer_find_sum,
                       jobconf = {
                        'mapred.map.tasks': 50,
                        'mapred.reduce.tasks': 1,
                        'mapreduce.reduce.cpu.vcores':8,
                        }
                      )
                
            ]
         elif self.options.runtype == 'countlinks':
            return [
                MRStep(mapper=self.mapper_links,
                       combiner=self.reducer_links,
                       reducer=self.reducer_links,
                       jobconf = {
                        'mapred.map.tasks': 300,
                        'mapred.reduce.tasks': 1,
                        'mapreduce.reduce.cpu.vcores':8,
                        })
            ]
         elif self.options.runtype == 'sumlinks':
            return [
                MRStep(mapper=self.mapssum_links,
                       combiner=self.mapsumreducer_links,
                       reducer=self.mapsumreducer_links,
                      jobconf = {
                        'mapred.map.tasks': 300,
                        'mapred.reduce.tasks': 1,
                        'mapreduce.reduce.cpu.vcores':8,
                        })
            ]
   
if __name__ == '__main__' and sys.argv[0].find('ipykernel') == -1:
    EDA.run()
# END STUDENT CODE 7.1
# Out:
# Overwriting eda.py

# %%
# !python eda.py -r hadoop --runtype countnodes 'hdfs:///user/andrewlam/HW7/Data/wikipedia/all-pages-indexed-in.txt' 'hdfs:///user/andrewlam/HW7/Data/wikipedia/all-pages-indexed-out.txt'
# Out:
# No configs found; falling back on auto-configuration
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Creating temp directory /tmp/eda.nileshbhoyar.20170709.115418.440807
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/nileshbhoyar/tmp/mrjob/eda.nileshbhoyar.20170709.115418.440807/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.map.tasks: mapreduce.job.maps
# mapred.reduce.tasks: mapreduce.job.reduces
# Running step 1 of 2...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob2146999763588708530.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 2
#   Adding a new node: /default-rack/10.251.253.170:50010
#   Adding a new node: /default-rack/10.251.237.214:50010
#   Adding a new node: /default-rack/10.251.249.90:50010
#   Adding a new node: /default-rack/10.251.240.186:50010
#   Adding a new node: /default-rack/10.251.253.202:50010
#   Adding a new node: /default-rack/10.251.253.174:50010
#   Adding a new node: /default-rack/10.251.249.146:50010
#   Adding a new node: /default-rack/10.251.240.106:50010
#   Adding a new node: /default-rack/10.251.237.66:50010
#   Adding a new node: /default-rack/10.251.249.154:50010
#   Adding a new node: /default-rack/10.251.237.158:50010
#   Adding a new node: /default-rack/10.251.236.214:50010
#   Adding a new node: /default-rack/10.251.236.126:50010
#   Adding a new node: /default-rack/10.251.240.178:50010
#   Adding a new node: /default-rack/10.251.235.85:50010
#   Adding a new node: /default-rack/10.251.253.214:50010
#   Adding a new node: /default-rack/10.251.235.73:50010
#   number of splits:501
#   Submitting tokens for job: job_1497906899862_3681
#   Submitted application application_1497906899862_3681
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_3681/
#   Running job: job_1497906899862_3681
#   Job job_1497906899862_3681 running in uber mode : false
#    map 0% reduce 0%
#    map 1% reduce 0%
#    map 2% reduce 0%
#    map 3% reduce 0%
#    map 4% reduce 0%
#    map 5% reduce 0%
#    map 6% reduce 0%
#    map 7% reduce 0%
#    map 8% reduce 0%
#    map 9% reduce 0%
#    map 10% reduce 0%
#    map 11% reduce 0%
#    map 12% reduce 0%
#    map 13% reduce 0%
#    map 14% reduce 0%
#    map 15% reduce 0%
#    map 16% reduce 0%
#    map 17% reduce 0%
#    map 18% reduce 0%
#    map 19% reduce 0%
#    map 20% reduce 0%
#    map 21% reduce 0%
#    map 22% reduce 0%
#    map 23% reduce 0%
#    map 24% reduce 0%
#    map 25% reduce 0%
#    map 26% reduce 0%
#    map 27% reduce 0%
#    map 28% reduce 0%
#    map 29% reduce 0%
#    map 30% reduce 0%
#    map 31% reduce 0%
#    map 32% reduce 0%
#    map 33% reduce 0%
#    map 34% reduce 0%
#    map 35% reduce 0%
#    map 36% reduce 0%
#    map 37% reduce 0%
#    map 38% reduce 0%
#    map 39% reduce 0%
#    map 40% reduce 0%
#    map 41% reduce 0%
#    map 42% reduce 0%
#    map 43% reduce 0%
#    map 44% reduce 0%
#    map 45% reduce 0%
#    map 46% reduce 0%
#    map 47% reduce 0%
#    map 48% reduce 0%
#    map 49% reduce 0%
#    map 50% reduce 0%
#    map 51% reduce 0%
#    map 52% reduce 0%
#    map 53% reduce 0%
#    map 54% reduce 0%
#    map 55% reduce 0%
#    map 56% reduce 0%
#    map 57% reduce 0%
#    map 58% reduce 0%
#    map 59% reduce 0%
#    map 60% reduce 0%
#    map 61% reduce 0%
#    map 62% reduce 0%
#    map 63% reduce 0%
#    map 64% reduce 0%
#    map 65% reduce 0%
#    map 66% reduce 0%
#    map 67% reduce 0%
#    map 68% reduce 0%
#    map 69% reduce 0%
#    map 70% reduce 0%
#    map 71% reduce 0%
#    map 72% reduce 0%
#    map 73% reduce 0%
#    map 74% reduce 0%
#    map 75% reduce 0%
#    map 76% reduce 0%
#    map 77% reduce 0%
#    map 78% reduce 0%
#    map 79% reduce 0%
#    map 80% reduce 0%
#    map 81% reduce 0%
#    map 82% reduce 0%
#    map 83% reduce 0%
#    map 84% reduce 0%
#    map 85% reduce 0%
#    map 86% reduce 0%
#    map 87% reduce 0%
#    map 88% reduce 0%
#    map 89% reduce 0%
#    map 90% reduce 0%
#    map 91% reduce 0%
#    map 92% reduce 0%
#    map 93% reduce 0%
#    map 94% reduce 0%
#    map 95% reduce 0%
#    map 96% reduce 0%
#    map 97% reduce 0%
#    map 98% reduce 0%
#    map 99% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 8%
#    map 100% reduce 15%
#    map 100% reduce 21%
#    map 100% reduce 30%
#    map 100% reduce 41%
#    map 100% reduce 46%
#    map 100% reduce 55%
#    map 100% reduce 61%
#    map 100% reduce 65%
#    map 100% reduce 66%
#    map 100% reduce 67%
#    map 100% reduce 68%
#    map 100% reduce 69%
#    map 100% reduce 70%
#    map 100% reduce 71%
#    map 100% reduce 72%
#    map 100% reduce 73%
#    map 100% reduce 74%
#    map 100% reduce 75%
#    map 100% reduce 76%
#    map 100% reduce 77%
#    map 100% reduce 78%
#    map 100% reduce 79%
#    map 100% reduce 80%
#    map 100% reduce 81%
#    map 100% reduce 82%
#    map 100% reduce 83%
#    map 100% reduce 84%
#    map 100% reduce 85%
#    map 100% reduce 86%
#    map 100% reduce 87%
#    map 100% reduce 88%
#    map 100% reduce 89%
#    map 100% reduce 90%
#    map 100% reduce 91%
#    map 100% reduce 92%
#    map 100% reduce 93%
#    map 100% reduce 94%
#    map 100% reduce 95%
#    map 100% reduce 96%
#    map 100% reduce 97%
#    map 100% reduce 98%
#    map 100% reduce 99%
#    map 100% reduce 100%
#   Job job_1497906899862_3681 completed successfully
#   Output directory: hdfs:///user/nileshbhoyar/tmp/mrjob/eda.nileshbhoyar.20170709.115418.440807/step-output/0000
# Counters: 50
# 	File Input Format Counters
# 		Bytes Read=4267098159
# 	File Output Format Counters
# 		Bytes Written=186388498
# 	File System Counters
# 		FILE: Number of bytes read=252672254
# 		FILE: Number of bytes written=1731839719
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=4267171552
# 		HDFS: Number of bytes written=186388498
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=1593
# 		HDFS: Number of write operations=60
# 	Job Counters
# 		Killed map tasks=2
# 		Launched map tasks=503
# 		Launched reduce tasks=30
# 		Rack-local map tasks=503
# 		Total megabyte-milliseconds taken by all map tasks=107750728704
# 		Total megabyte-milliseconds taken by all reduce tasks=10861911040
# 		Total time spent by all map tasks (ms)=70150214
# 		Total time spent by all maps in occupied slots (ms)=210450642
# 		Total time spent by all reduce tasks (ms)=4242934
# 		Total time spent by all reduces in occupied slots (ms)=21214670
# 		Total vcore-milliseconds taken by all map tasks=70150214
# 		Total vcore-milliseconds taken by all reduce tasks=16971736
# 	Map-Reduce Framework
# 		CPU time spent (ms)=21955850
# 		Combine input records=304225425
# 		Combine output records=225948898
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=200122
# 		Input split bytes=73393
# 		Map input records=19997311
# 		Map output bytes=3724491506
# 		Map output materialized bytes=1408341470
# 		Map output records=304225425
# 		Merged Map outputs=15030
# 		Physical memory (bytes) snapshot=421727617024
# 		Reduce input groups=15192277
# 		Reduce input records=225948898
# 		Reduce output records=15192277
# 		Reduce shuffle bytes=1408341470
# 		Shuffled Maps =15030
# 		Spilled Records=451897796
# 		Total committed heap usage (bytes)=848510320640
# 		Virtual memory (bytes) snapshot=1202668748800
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.map.tasks: mapreduce.job.maps
# mapred.reduce.tasks: mapreduce.job.reduces
# Running step 2 of 2...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob1780814051203507557.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 30
#   number of splits:60
#   Submitting tokens for job: job_1497906899862_3689
#   Submitted application application_1497906899862_3689
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_3689/
#   Running job: job_1497906899862_3689
#   Job job_1497906899862_3689 running in uber mode : false
#    map 0% reduce 0%
#    map 2% reduce 0%
#    map 8% reduce 0%
#    map 9% reduce 0%
#    map 12% reduce 0%
#    map 13% reduce 0%
#    map 17% reduce 0%
#    map 22% reduce 0%
#    map 26% reduce 0%
#    map 27% reduce 0%
#    map 28% reduce 0%
#    map 29% reduce 0%
#    map 30% reduce 0%
#    map 31% reduce 0%
#    map 32% reduce 0%
#    map 33% reduce 0%
#    map 35% reduce 0%
#    map 36% reduce 0%
#    map 37% reduce 0%
#    map 38% reduce 0%
#    map 39% reduce 0%
#    map 41% reduce 0%
#    map 42% reduce 0%
#    map 44% reduce 0%
#    map 46% reduce 0%
#    map 48% reduce 0%
#    map 50% reduce 0%
#    map 52% reduce 0%
#    map 54% reduce 0%
#    map 56% reduce 0%
#    map 58% reduce 0%
#    map 60% reduce 0%
#    map 61% reduce 0%
#    map 63% reduce 0%
#    map 64% reduce 0%
#    map 65% reduce 0%
#    map 67% reduce 0%
#    map 69% reduce 0%
#    map 71% reduce 0%
#    map 73% reduce 0%
#    map 75% reduce 0%
#    map 77% reduce 0%
#    map 80% reduce 0%
#    map 82% reduce 0%
#    map 85% reduce 0%
#    map 89% reduce 0%
#    map 92% reduce 0%
#    map 94% reduce 0%
#    map 99% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 67%
#    map 100% reduce 100%
#   Job job_1497906899862_3689 completed successfully
#   Output directory: hdfs:///user/nileshbhoyar/tmp/mrjob/eda.nileshbhoyar.20170709.115418.440807/output
# Counters: 50
# 	File Input Format Counters
# 		Bytes Read=188588068
# 	File Output Format Counters
# 		Bytes Written=14
# 	File System Counters
# 		FILE: Number of bytes read=6441503
# 		FILE: Number of bytes written=20953348
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=188599108
# 		HDFS: Number of bytes written=14
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=183
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=4
# 		Launched map tasks=64
# 		Launched reduce tasks=1
# 		Rack-local map tasks=64
# 		Total megabyte-milliseconds taken by all map tasks=5421061632
# 		Total megabyte-milliseconds taken by all reduce tasks=757434880
# 		Total time spent by all map tasks (ms)=3529337
# 		Total time spent by all maps in occupied slots (ms)=10588011
# 		Total time spent by all reduce tasks (ms)=295873
# 		Total time spent by all reduces in occupied slots (ms)=1479365
# 		Total vcore-milliseconds taken by all map tasks=3529337
# 		Total vcore-milliseconds taken by all reduce tasks=2366984
# 	Map-Reduce Framework
# 		CPU time spent (ms)=1496940
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=13188
# 		Input split bytes=11040
# 		Map input records=15192277
# 		Map output bytes=106345939
# 		Map output materialized bytes=6442465
# 		Map output records=15192277
# 		Merged Map outputs=60
# 		Physical memory (bytes) snapshot=49175060480
# 		Reduce input groups=1
# 		Reduce input records=15192277
# 		Reduce output records=1
# 		Reduce shuffle bytes=6442465
# 		Shuffled Maps =60
# 		Spilled Records=30384554
# 		Total committed heap usage (bytes)=96202129408
# 		Virtual memory (bytes) snapshot=135476633600
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/nileshbhoyar/tmp/mrjob/eda.nileshbhoyar.20170709.115418.440807/output...
# null	15192277
# Removing HDFS temp directory hdfs:///user/nileshbhoyar/tmp/mrjob/eda.nileshbhoyar.20170709.115418.440807...
# Removing temp directory /tmp/eda.nileshbhoyar.20170709.115418.440807...

# %% [markdown]
# ### No of node 15192277

# %%
# START STUDENT CODE 7.3
# (ADD CELLS AS NEEDED)
# !python eda.py -r hadoop --runtype sumlinks 'hdfs:///user/andrewlam/HW7/Data/wikipedia/all-pages-indexed-in.txt' 'hdfs:///user/andrewlam/HW7/Data/wikipedia/all-pages-indexed-out.txt' | cut -f 2
# END STUDENT CODE 7.3
# Out:
# No configs found; falling back on auto-configuration
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Creating temp directory /tmp/eda.nileshbhoyar.20170709.121226.405242
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/nileshbhoyar/tmp/mrjob/eda.nileshbhoyar.20170709.121226.405242/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.map.tasks: mapreduce.job.maps
# mapred.reduce.tasks: mapreduce.job.reduces
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob2575634436014623526.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 2
#   Adding a new node: /default-rack/10.251.249.90:50010
#   Adding a new node: /default-rack/10.251.253.170:50010
#   Adding a new node: /default-rack/10.251.237.214:50010
#   Adding a new node: /default-rack/10.251.253.202:50010
#   Adding a new node: /default-rack/10.251.240.186:50010
#   Adding a new node: /default-rack/10.251.249.146:50010
#   Adding a new node: /default-rack/10.251.240.106:50010
#   Adding a new node: /default-rack/10.251.253.174:50010
#   Adding a new node: /default-rack/10.251.237.66:50010
#   Adding a new node: /default-rack/10.251.249.154:50010
#   Adding a new node: /default-rack/10.251.237.158:50010
#   Adding a new node: /default-rack/10.251.236.126:50010
#   Adding a new node: /default-rack/10.251.236.214:50010
#   Adding a new node: /default-rack/10.251.240.178:50010
#   Adding a new node: /default-rack/10.251.235.85:50010
#   Adding a new node: /default-rack/10.251.253.214:50010
#   Adding a new node: /default-rack/10.251.235.73:50010
#   number of splits:301
#   Submitting tokens for job: job_1497906899862_3698
#   Submitted application application_1497906899862_3698
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_3698/
#   Running job: job_1497906899862_3698
#   Job job_1497906899862_3698 running in uber mode : false
#    map 0% reduce 0%
#    map 1% reduce 0%
#    map 2% reduce 0%
#    map 3% reduce 0%
#    map 4% reduce 0%
#    map 5% reduce 0%
#    map 6% reduce 0%
#    map 7% reduce 0%
#    map 8% reduce 0%
#    map 9% reduce 0%
#    map 10% reduce 0%
#    map 11% reduce 0%
#    map 12% reduce 0%
#    map 13% reduce 0%
#    map 15% reduce 0%
#    map 16% reduce 0%
#    map 18% reduce 0%
#    map 19% reduce 0%
#    map 20% reduce 0%
#    map 21% reduce 0%
#    map 23% reduce 0%
#    map 24% reduce 0%
#    map 25% reduce 0%
#    map 26% reduce 0%
#    map 28% reduce 0%
#    map 29% reduce 0%
#    map 31% reduce 0%
#    map 32% reduce 0%
#    map 34% reduce 0%
#    map 35% reduce 0%
#    map 37% reduce 0%
#    map 39% reduce 0%
#    map 42% reduce 0%
#    map 43% reduce 0%
#    map 45% reduce 0%
#    map 47% reduce 0%
#    map 48% reduce 0%
#    map 49% reduce 0%
#    map 51% reduce 0%
#    map 52% reduce 0%
#    map 53% reduce 0%
#    map 55% reduce 0%
#    map 56% reduce 0%
#    map 57% reduce 0%
#    map 59% reduce 0%
#    map 60% reduce 0%
#    map 61% reduce 0%
#    map 62% reduce 0%
#    map 63% reduce 0%
#    map 64% reduce 0%
#    map 65% reduce 0%
#    map 66% reduce 0%
#    map 67% reduce 0%
#    map 68% reduce 0%
#    map 70% reduce 0%
#    map 71% reduce 0%
#    map 74% reduce 0%
#    map 76% reduce 0%
#    map 78% reduce 0%
#    map 81% reduce 0%
#    map 82% reduce 0%
#    map 84% reduce 0%
#    map 87% reduce 0%
#    map 89% reduce 0%
#    map 90% reduce 0%
#    map 91% reduce 0%
#    map 93% reduce 0%
#    map 95% reduce 0%
#    map 96% reduce 0%
#    map 98% reduce 0%
#    map 99% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_3698 completed successfully
#   Output directory: hdfs:///user/nileshbhoyar/tmp/mrjob/eda.nileshbhoyar.20170709.121226.405242/output
# Counters: 50
# 	File Input Format Counters
# 		Bytes Read=4257107563
# 	File Output Format Counters
# 		Bytes Written=15
# 	File System Counters
# 		FILE: Number of bytes read=1876
# 		FILE: Number of bytes written=40089765
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=4257151658
# 		HDFS: Number of bytes written=15
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=906
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=2
# 		Launched map tasks=303
# 		Launched reduce tasks=1
# 		Rack-local map tasks=303
# 		Total megabyte-milliseconds taken by all map tasks=19557708288
# 		Total megabyte-milliseconds taken by all reduce tasks=11315200
# 		Total time spent by all map tasks (ms)=12732883
# 		Total time spent by all maps in occupied slots (ms)=38198649
# 		Total time spent by all reduce tasks (ms)=4420
# 		Total time spent by all reduces in occupied slots (ms)=22100
# 		Total vcore-milliseconds taken by all map tasks=12732883
# 		Total vcore-milliseconds taken by all reduce tasks=35360
# 	Map-Reduce Framework
# 		CPU time spent (ms)=3910450
# 		Combine input records=19997311
# 		Combine output records=301
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=65607
# 		Input split bytes=44095
# 		Map input records=19997311
# 		Map output bytes=145682407
# 		Map output materialized bytes=9032
# 		Map output records=19997311
# 		Merged Map outputs=301
# 		Physical memory (bytes) snapshot=243817185280
# 		Reduce input groups=1
# 		Reduce input records=301
# 		Reduce output records=1
# 		Reduce shuffle bytes=9032
# 		Shuffled Maps =301
# 		Spilled Records=602
# 		Total committed heap usage (bytes)=473998819328
# 		Virtual memory (bytes) snapshot=665573384192
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/nileshbhoyar/tmp/mrjob/eda.nileshbhoyar.20170709.121226.405242/output...
# Removing HDFS temp directory hdfs:///user/nileshbhoyar/tmp/mrjob/eda.nileshbhoyar.20170709.121226.405242...
# Removing temp directory /tmp/eda.nileshbhoyar.20170709.121226.405242...
# 284228114

# %% [markdown]
# ## Total links 284228114

# %%
# !python eda.py -r hadoop --runtype countlinks  'hdfs:///user/andrewlam/HW7/Data/wikipedia/all-pages-indexed-in.txt' 'hdfs:///user/andrewlam/HW7/Data/wikipedia/all-pages-indexed-out.txt' >linksfrequency.txt
# Out:
# No configs found; falling back on auto-configuration
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Creating temp directory /tmp/eda.nileshbhoyar.20170709.122027.316314
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/nileshbhoyar/tmp/mrjob/eda.nileshbhoyar.20170709.122027.316314/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Detected hadoop configuration property names that do not match hadoop version 2.7.3:
# The have been translated as follows
#  mapred.map.tasks: mapreduce.job.maps
# mapred.reduce.tasks: mapreduce.job.reduces
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob4695582563642160262.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 2
#   Adding a new node: /default-rack/10.251.249.90:50010
#   Adding a new node: /default-rack/10.251.237.214:50010
#   Adding a new node: /default-rack/10.251.253.170:50010
#   Adding a new node: /default-rack/10.251.240.186:50010
#   Adding a new node: /default-rack/10.251.253.202:50010
#   Adding a new node: /default-rack/10.251.253.174:50010
#   Adding a new node: /default-rack/10.251.240.106:50010
#   Adding a new node: /default-rack/10.251.249.146:50010
#   Adding a new node: /default-rack/10.251.237.66:50010
#   Adding a new node: /default-rack/10.251.249.154:50010
#   Adding a new node: /default-rack/10.251.237.158:50010
#   Adding a new node: /default-rack/10.251.236.126:50010
#   Adding a new node: /default-rack/10.251.236.214:50010
#   Adding a new node: /default-rack/10.251.240.178:50010
#   Adding a new node: /default-rack/10.251.235.85:50010
#   Adding a new node: /default-rack/10.251.253.214:50010
#   Adding a new node: /default-rack/10.251.235.73:50010
#   number of splits:301
#   Submitting tokens for job: job_1497906899862_3706
#   Submitted application application_1497906899862_3706
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_3706/
#   Running job: job_1497906899862_3706
#   Job job_1497906899862_3706 running in uber mode : false
#    map 0% reduce 0%
#    map 2% reduce 0%
#    map 3% reduce 0%
#    map 4% reduce 0%
#    map 5% reduce 0%
#    map 6% reduce 0%
#    map 8% reduce 0%
#    map 10% reduce 0%
#    map 11% reduce 0%
#    map 12% reduce 0%
#    map 13% reduce 0%
#    map 15% reduce 0%
#    map 17% reduce 0%
#    map 18% reduce 0%
#    map 20% reduce 0%
#    map 21% reduce 0%
#    map 22% reduce 0%
#    map 23% reduce 0%
#    map 25% reduce 0%
#    map 26% reduce 0%
#    map 27% reduce 0%
#    map 29% reduce 0%
#    map 30% reduce 0%
#    map 31% reduce 0%
#    map 33% reduce 0%
#    map 34% reduce 0%
#    map 35% reduce 0%
#    map 36% reduce 0%
#    map 38% reduce 0%
#    map 40% reduce 0%
#    map 42% reduce 0%
#    map 44% reduce 0%
#    map 46% reduce 0%
#    map 47% reduce 0%
#    map 50% reduce 0%
#    map 51% reduce 0%
#    map 52% reduce 0%
#    map 55% reduce 0%
#    map 56% reduce 0%
#    map 58% reduce 0%
#    map 60% reduce 0%
#    map 61% reduce 0%
#    map 62% reduce 0%
#    map 63% reduce 0%
#    map 64% reduce 0%
#    map 65% reduce 0%
#    map 66% reduce 0%
#    map 67% reduce 0%
#    map 68% reduce 0%
#    map 69% reduce 0%
#    map 71% reduce 0%
#    map 73% reduce 0%
#    map 75% reduce 0%
#    map 78% reduce 0%
#    map 82% reduce 0%
#    map 84% reduce 0%
#    map 86% reduce 0%
#    map 88% reduce 0%
#    map 90% reduce 0%
#    map 91% reduce 0%
#    map 93% reduce 0%
#    map 95% reduce 0%
#    map 96% reduce 0%
#    map 97% reduce 0%
#    map 98% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1497906899862_3706 completed successfully
#   Output directory: hdfs:///user/nileshbhoyar/tmp/mrjob/eda.nileshbhoyar.20170709.122027.316314/output
# Counters: 50
# 	File Input Format Counters
# 		Bytes Read=4257107563
# 	File Output Format Counters
# 		Bytes Written=35568
# 	File System Counters
# 		FILE: Number of bytes read=276987
# 		FILE: Number of bytes written=41146806
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=4257151658
# 		HDFS: Number of bytes written=35568
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=906
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=2
# 		Launched map tasks=303
# 		Launched reduce tasks=1
# 		Rack-local map tasks=303
# 		Total megabyte-milliseconds taken by all map tasks=19449403392
# 		Total megabyte-milliseconds taken by all reduce tasks=17461760
# 		Total time spent by all map tasks (ms)=12662372
# 		Total time spent by all maps in occupied slots (ms)=37987116
# 		Total time spent by all reduce tasks (ms)=6821
# 		Total time spent by all reduces in occupied slots (ms)=34105
# 		Total vcore-milliseconds taken by all map tasks=12662372
# 		Total vcore-milliseconds taken by all reduce tasks=54568
# 	Map-Reduce Framework
# 		CPU time spent (ms)=3918870
# 		Combine input records=19997311
# 		Combine output records=145068
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=64279
# 		Input split bytes=44095
# 		Map input records=19997311
# 		Map output bytes=85690474
# 		Map output materialized bytes=789150
# 		Map output records=19997311
# 		Merged Map outputs=301
# 		Physical memory (bytes) snapshot=243479887872
# 		Reduce input groups=4872
# 		Reduce input records=145068
# 		Reduce output records=4872
# 		Reduce shuffle bytes=789150
# 		Shuffled Maps =301
# 		Spilled Records=290136
# 		Total committed heap usage (bytes)=473998819328
# 		Virtual memory (bytes) snapshot=665635049472
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Streaming final output from hdfs:///user/nileshbhoyar/tmp/mrjob/eda.nileshbhoyar.20170709.122027.316314/output...
# Removing HDFS temp directory hdfs:///user/nileshbhoyar/tmp/mrjob/eda.nileshbhoyar.20170709.122027.316314...
# Removing temp directory /tmp/eda.nileshbhoyar.20170709.122027.316314...

# %%
data =  np.loadtxt('linksfrequency.txt')
bins, weights = data.astype(int).T
plt.hist(bins, 20, weights = weights)
# Out:
# (array([  1.99971220e+07,   1.25000000e+02,   2.70000000e+01,
#           1.90000000e+01,   6.00000000e+00,   4.00000000e+00,
#           5.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00]),
#  array([  1.00000000e+00,   1.98702000e+04,   3.97394000e+04,
#           5.96086000e+04,   7.94778000e+04,   9.93470000e+04,
#           1.19216200e+05,   1.39085400e+05,   1.58954600e+05,
#           1.78823800e+05,   1.98693000e+05,   2.18562200e+05,
#           2.38431400e+05,   2.58300600e+05,   2.78169800e+05,
#           2.98039000e+05,   3.17908200e+05,   3.37777400e+05,
#           3.57646600e+05,   3.77515800e+05,   3.97385000e+05]),
#  <a list of 20 Patch objects>)

# %%
# Use the histogram function to bin the data
new_bins = np.linspace(min(bins), max(bins), num=100)
counts, bin_edges = np.histogram(weights, bins=new_bins, normed=True)

# Now find the cdf
cdf = np.cumsum(counts)

# And finally plot the cdf
plt.plot(bin_edges[1:], cdf)

plt.show()

# %% [markdown]
# ## Average Links
#     = 284228114 /15192277
#     =18.70872378116855

# %% [markdown]
# <h1 style="color:#021353;">HW 7.4: Shortest path graph distances (Wikipedia)</h1>
# <div style="margin:10px;border-left:5px solid #eee;">
# <pre style="font-family:sans-serif;background-color:transparent">
# Using MRJob, find shortest path graph distances in the Wikipedia network on the AWS cloud.
# Reuse your code from 7.2, but once again be warned of Wikipedia being a directed network.
# To be sure of your code's functionality in this context, run a systems test on the directed_toy.txt network.
#
# When running your code on the Wikipedia network, proof its function by running the job:
#
# - shortest path from "Ireland" (index=6176135) to "University of California, Berkeley" (index=13466359),
#
# and show your code's output. Show the shortest path in terms of just page IDS but also in terms of the name of page (show of your MapReduce join skills!!)
#
# Once your code is running, find some other shortest paths and report your results.
# </pre>
# </div>

# %%
# START STUDENT CODE 7.4
# (ADD CELLS AS NEEDED)
# !hdfs dfs -mkdir hdfs:///user/nileshbhoyar/output/
# !hdfs dfs -rm -r hdfs:///user/nileshbhoyar/output/HW732/
# !python sssp_init.py -r hadoop --firstnode '6176135' --output-dir="hdfs:///user/nileshbhoyar/output/HW732/"\
                    --no-output \
                    'hdfs:///user/andrewlam/HW7/Data/wikipedia/all-pages-indexed-out.txt' 
# END STUDENT CODE 7.4
# Out:
# mkdir: `hdfs:/user/nileshbhoyar/output': File exists
# 17/07/09 14:07:17 INFO fs.TrashPolicyDefault: Namenode trash configuration: Deletion interval = 5760 minutes, Emptier interval = 360 minutes.
# Moved: 'hdfs://nn-ia.s3s.altiscale.com:8020/user/nileshbhoyar/output/HW732' to trash at: hdfs://nn-ia.s3s.altiscale.com:8020/user/nileshbhoyar/.Trash/Current
# No configs found; falling back on auto-configuration
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Creating temp directory /tmp/sssp_init.nileshbhoyar.20170709.140718.221066
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/nileshbhoyar/tmp/mrjob/sssp_init.nileshbhoyar.20170709.140718.221066/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob4169977903094761990.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:8
#   Submitting tokens for job: job_1497906899862_3828
#   Submitted application application_1497906899862_3828
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_3828/
#   Running job: job_1497906899862_3828
#   Job job_1497906899862_3828 running in uber mode : false
#    map 0% reduce 0%
#    map 2% reduce 0%
#    map 4% reduce 0%
#    map 6% reduce 0%
#    map 8% reduce 0%
#    map 11% reduce 0%
#    map 13% reduce 0%
#    map 15% reduce 0%
#    map 17% reduce 0%
#    map 20% reduce 0%
#    map 22% reduce 0%
#    map 24% reduce 0%
#    map 26% reduce 0%
#    map 28% reduce 0%
#    map 31% reduce 0%
#    map 33% reduce 0%
#    map 35% reduce 0%
#    map 38% reduce 0%
#    map 40% reduce 0%
#    map 42% reduce 0%
#    map 44% reduce 0%
#    map 47% reduce 0%
#    map 49% reduce 0%
#    map 51% reduce 0%
#    map 53% reduce 0%
#    map 56% reduce 0%
#    map 58% reduce 0%
#    map 60% reduce 0%
#    map 62% reduce 0%
#    map 65% reduce 0%
#    map 67% reduce 0%
#    map 69% reduce 0%
#    map 72% reduce 0%
#    map 74% reduce 0%
#    map 76% reduce 0%
#    map 79% reduce 0%
#    map 81% reduce 0%
#    map 83% reduce 0%
#    map 85% reduce 0%
#    map 87% reduce 0%
#    map 89% reduce 0%
#    map 91% reduce 0%
#    map 92% reduce 0%
#    map 93% reduce 0%
#    map 94% reduce 0%
#    map 95% reduce 0%
#    map 96% reduce 0%
#    map 97% reduce 0%
#    map 98% reduce 0%
#    map 99% reduce 0%
#    map 100% reduce 0%
#   Job job_1497906899862_3828 completed successfully
#   Output directory: hdfs:///user/nileshbhoyar/output/HW732/
# Counters: 30
# 	File Input Format Counters
# 		Bytes Read=2091377120
# 	File Output Format Counters
# 		Bytes Written=2263898298
# 	File System Counters
# 		FILE: Number of bytes read=0
# 		FILE: Number of bytes written=1054904
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=2091378296
# 		HDFS: Number of bytes written=2263898298
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=40
# 		HDFS: Number of write operations=16
# 	Job Counters
# 		Launched map tasks=8
# 		Rack-local map tasks=8
# 		Total megabyte-milliseconds taken by all map tasks=1736962560
# 		Total time spent by all map tasks (ms)=1130835
# 		Total time spent by all maps in occupied slots (ms)=3392505
# 		Total time spent by all reduces in occupied slots (ms)=0
# 		Total vcore-milliseconds taken by all map tasks=1130835
# 	Map-Reduce Framework
# 		CPU time spent (ms)=1161340
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=1785
# 		Input split bytes=1176
# 		Map input records=5781290
# 		Map output records=5781290
# 		Merged Map outputs=0
# 		Physical memory (bytes) snapshot=2257440768
# 		Spilled Records=0
# 		Total committed heap usage (bytes)=12329156608
# 		Virtual memory (bytes) snapshot=17573359616
# Removing HDFS temp directory hdfs:///user/nileshbhoyar/tmp/mrjob/sssp_init.nileshbhoyar.20170709.140718.221066...
# Removing temp directory /tmp/sssp_init.nileshbhoyar.20170709.140718.221066...

# %%
from sssp import MRSSSP
inputstate = 'hdfs:///user/nileshbhoyar/output/HW732/'
inputDir='hdfs:///user/nileshbhoyar/output/HW732/'
outputDir = inputDir + 'tmp1/'

notexit =None
for i in range(1,100):
    notexit = None
    # !hdfs dfs -rm -r -f -skipTrash $outputDir
    mr_job = MRSSSP(args=[
            inputDir,
      
            '-r', 'hadoop',
            '--no-output',
            '--output-dir', outputDir
        ])
    
    with mr_job.make_runner() as runner:
                # Run MRJob
        runner.run()
        if len(runner.counters()[0]) == 0 or i > 4:
            for line in runner.stream_output():
                    out = mr_job.parse_output_line(line)
                    value = out[1]
                    
                    if  value[2] == 'Q':
                        notexit = 'X'
                    
                    if out[0] == '13466359' and out[1][2] == 'V':
                        path = out[1][3]
                        print path ,'and distance',out[1][1]
                        
    # !echo "**********Iteration {i}**************"
    #!cat {filenameTemp  }           
    inputDir = inputstate  + 'tmp' + str(i) + '/'
    outputDir = inputstate  + 'tmp' + str(i + 1)
    #if notexit == None:
     #   break
    if len(runner.counters()[0]) == 0 :
        break
# Out:
# **********Iteration 1**************
# **********Iteration 2**************
# **********Iteration 3**************
# **********Iteration 4**************
# [u'11607791', u'13466359'] and distance 3
# **********Iteration 5**************
# [u'11607791', u'13466359'] and distance 3
# **********Iteration 6**************
# [u'11607791', u'13466359'] and distance 3
# **********Iteration 7**************

# %% [markdown]
# ## Ideally I should have let it run till it completes i.e. no node with status "Q". But I am comfertable with answer as it is not changing in many iterations so stopping it so that I can do next part.

# %%
# !rm indices.txt
# !hdfs dfs -copyToLocal hdfs:/user/andrewlam/HW7/Data/wikipedia/indices.txt indices.txt
dictionary = {}
with open("indices.txt", 'r') as f:
        for line in f:
            fields = line.strip().split('\t')

            # Perform the join

            if fields[1] in path:
                dictionary[fields[1]] = fields[0]
# !rm indices.txt

# %%
print dictionary
# Out:
# {'11607791': 'Seamus Heaney', '13466359': 'University of California, Berkeley'}

# %% [markdown]
# ## Shortest path University of harvard (13467846)to University of Berkeley'13466359'

# %%
# START STUDENT CODE 7.4
# (ADD CELLS AS NEEDED)
# !hdfs dfs -mkdir hdfs:///user/nileshbhoyar/output/
# !hdfs dfs -rm -r hdfs:///user/nileshbhoyar/output/HW733/
# !python sssp_init.py -r hadoop --firstnode '13467846' --output-dir="hdfs:///user/nileshbhoyar/output/HW733/"\
                    --no-output \
                    'hdfs:///user/andrewlam/HW7/Data/wikipedia/all-pages-indexed-out.txt'
# Out:
# mkdir: `hdfs:/user/nileshbhoyar/output': File exists
# rm: `hdfs:///user/nileshbhoyar/output/HW733/': No such file or directory
# No configs found; falling back on auto-configuration
# Looking for hadoop binary in /opt/hadoop/bin...
# Found hadoop binary: /opt/hadoop/bin/hadoop
# Creating temp directory /tmp/sssp_init.nileshbhoyar.20170711.044645.413458
# Using Hadoop version 2.7.3
# Copying local files to hdfs:///user/nileshbhoyar/tmp/mrjob/sssp_init.nileshbhoyar.20170711.044645.413458/files/...
# Looking for Hadoop streaming jar in /opt/hadoop...
# Found Hadoop streaming jar: /opt/hadoop/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar
# Running step 1 of 1...
#   packageJobJar: [] [/opt/hadoop-2.7.3/share/hadoop/tools/lib/hadoop-streaming-2.7.3.jar] /tmp/streamjob3760371630820849237.jar tmpDir=null
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Timeline service address: http://rm-ia.s3s.altiscale.com:8188/ws/v1/timeline/
#   Connecting to ResourceManager at rm-ia.s3s.altiscale.com/10.251.255.108:8032
#   Connecting to Application History server at rm-ia.s3s.altiscale.com/10.251.255.108:10200
#   Loaded native gpl library from the embedded binaries
#   Successfully loaded & initialized native-lzo library [hadoop-lzo rev d62701d4d05dfa6115bbaf8d9dff002df142e62d]
#   Total input paths to process : 1
#   number of splits:8
#   Submitting tokens for job: job_1497906899862_4861
#   Submitted application application_1497906899862_4861
#   The url to track the job: http://rm-ia.s3s.altiscale.com:8088/proxy/application_1497906899862_4861/
#   Running job: job_1497906899862_4861
#   Job job_1497906899862_4861 running in uber mode : false
#    map 0% reduce 0%
#    map 1% reduce 0%
#    map 3% reduce 0%
#    map 5% reduce 0%
#    map 6% reduce 0%
#    map 7% reduce 0%
#    map 8% reduce 0%
#    map 10% reduce 0%
#    map 12% reduce 0%
#    map 14% reduce 0%
#    map 15% reduce 0%
#    map 17% reduce 0%
#    map 19% reduce 0%
#    map 20% reduce 0%
#    map 21% reduce 0%
#    map 22% reduce 0%
#    map 23% reduce 0%
#    map 24% reduce 0%
#    map 25% reduce 0%
#    map 26% reduce 0%
#    map 27% reduce 0%
#    map 28% reduce 0%
#    map 29% reduce 0%
#    map 30% reduce 0%
#    map 31% reduce 0%
#    map 32% reduce 0%
#    map 33% reduce 0%
#    map 34% reduce 0%
#    map 35% reduce 0%
#    map 36% reduce 0%
#    map 37% reduce 0%
#    map 38% reduce 0%
#    map 39% reduce 0%
#    map 40% reduce 0%
#    map 41% reduce 0%
#    map 42% reduce 0%
#    map 43% reduce 0%
#    map 44% reduce 0%
#    map 45% reduce 0%
#    map 46% reduce 0%
#    map 47% reduce 0%
#    map 48% reduce 0%
#    map 49% reduce 0%
#    map 50% reduce 0%
#    map 51% reduce 0%
#    map 52% reduce 0%
#    map 53% reduce 0%
#    map 54% reduce 0%
#    map 55% reduce 0%
#    map 56% reduce 0%
#    map 57% reduce 0%
#    map 58% reduce 0%
#    map 59% reduce 0%
#    map 60% reduce 0%
#    map 61% reduce 0%
#    map 62% reduce 0%
#    map 63% reduce 0%
#    map 64% reduce 0%
#    map 66% reduce 0%
#    map 67% reduce 0%
#    map 68% reduce 0%
#    map 69% reduce 0%
#    map 71% reduce 0%
#    map 72% reduce 0%
#    map 73% reduce 0%
#    map 74% reduce 0%
#    map 75% reduce 0%
#    map 77% reduce 0%
#    map 78% reduce 0%
#    map 79% reduce 0%
#    map 80% reduce 0%
#    map 81% reduce 0%
#    map 82% reduce 0%
#    map 83% reduce 0%
#    map 84% reduce 0%
#    map 86% reduce 0%
#    map 88% reduce 0%
#    map 90% reduce 0%
#    map 91% reduce 0%
#    map 92% reduce 0%
#    map 93% reduce 0%
#    map 94% reduce 0%
#    map 95% reduce 0%
#    map 96% reduce 0%
#    map 97% reduce 0%
#    map 98% reduce 0%
#    map 99% reduce 0%
#    map 100% reduce 0%
#   Job job_1497906899862_4861 completed successfully
#   Output directory: hdfs:///user/nileshbhoyar/output/HW733/
# Counters: 30
# 	File Input Format Counters
# 		Bytes Read=2091377120
# 	File Output Format Counters
# 		Bytes Written=2263898316
# 	File System Counters
# 		FILE: Number of bytes read=0
# 		FILE: Number of bytes written=1054912
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=2091378296
# 		HDFS: Number of bytes written=2263898316
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=40
# 		HDFS: Number of write operations=16
# 	Job Counters
# 		Launched map tasks=8
# 		Rack-local map tasks=8
# 		Total megabyte-milliseconds taken by all map tasks=2625666048
# 		Total time spent by all map tasks (ms)=1709418
# 		Total time spent by all maps in occupied slots (ms)=5128254
# 		Total time spent by all reduces in occupied slots (ms)=0
# 		Total vcore-milliseconds taken by all map tasks=1709418
# 	Map-Reduce Framework
# 		CPU time spent (ms)=1655930
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=4139
# 		Input split bytes=1176
# 		Map input records=5781290
# 		Map output records=5781290
# 		Merged Map outputs=0
# 		Physical memory (bytes) snapshot=2224041984
# 		Spilled Records=0
# 		Total committed heap usage (bytes)=12388925440
# 		Virtual memory (bytes) snapshot=17530773504
# Removing HDFS temp directory hdfs:///user/nileshbhoyar/tmp/mrjob/sssp_init.nileshbhoyar.20170711.044645.413458...
# Removing temp directory /tmp/sssp_init.nileshbhoyar.20170711.044645.413458...

# %%
# !rm indices.txt
# !hdfs dfs -copyToLocal hdfs:/user/andrewlam/HW7/Data/wikipedia/indices.txt indices.txt
dictionary = {}
with open("indices.txt", 'r') as f:
        for line in f:
            fields = line.strip().split('\t')

            # Perform the join

            if fields[1] in path:
                dictionary[fields[1]] = fields[0]
# !rm indices.txt

# %% [markdown]
# <h1 style="color:#021353;">HW 7.5: Conceptual exercise: Largest single-source network distances</h1>
# <div style="margin:10px;border-left:5px solid #eee;">
# <pre style="font-family:sans-serif;background-color:transparent">
# Suppose you wanted to find the largest network distance from a single source,
# i.e., a node that is the furthest (but still reachable) from a single source.
#
# How would you implement this task?
# How is this different from finding the shortest path graph distances?
#
# Is this task more difficult to implement than the shortest path distance?
#
# As you respond, please comment on program structure, runtimes, iterations, general system requirements, etc...
# </pre>
# </div>

# %% [markdown]
# #### START STUDENT CODE 7.5
#
#     This is longest path problem , which is NP hard.
#
#     Finding the longest path problem does not have optimal substructure, and we lose the ability to use dynamic programming . To see that the longest path problem does not have optimal substructure. We will have to enumerate all the paths and find the longest one.  But this means there can be exponentially many such paths so kind of unsolvable for large data even with map reduce.
#
#     But directed acyclic graph does have optimal structure and can be solved as we solved the SSSP.
#
#     Algorithm will look like this:-
#
#     1.  Find a topological ordering of the given DAG.
#     2. For each vertex v of the DAG, in the topological ordering, compute the length of the longest path ending at v by looking at its incoming neighbors and adding one to the maximum length recorded for those neighbors. If v has no incoming neighbors, set the length of the longest path ending at v to zero. In either case, record this number so that later steps of the algorithm can access it.
#
#
#
#
# http://www.mathcs.emory.edu/~cheung/Courses/171/Syllabus/11-Graph/Docs/longest-path-in-dag.pdf

# %%
# END STUDENT CODE 7.5

# %% [markdown]
# <h1 style="color:#021353;">HW 7.5.1: </h1>
# <div style="margin:10px;border-left:5px solid #eee;">
# <pre style="font-family:sans-serif;background-color:transparent">
# Can we utilize combiners in the HW 7 to perform the shortest path implementation?
# Does order inversion help with the HW 7 shortest path implementation?
# </pre>
# </div>

# %% [markdown]
# ### Does order inversion help with the HW 7 shortest path implementation?
#     Using the order inversion pattern can simplify and speed up Reducer but NOT a mandatory thing for accuracy of algorithm.
#
# ### Can we utilize combiners in the HW 7 to perform the shortest path implementation?
# Yes we can.  this will help in shuffuling lot of intermediate values.

# %%
# START STUDENT CODE 7.5.1

# %%
# END STUDENT CODE 7.5.1

# %% [markdown]
# <h1 style="color:#021353;">HW 7.5.2: Combiners: OPTIONAL </h1>
# <div style="margin:10px;border-left:5px solid #eee;">
# <pre style="font-family:sans-serif;background-color:transparent">
# Implement combiners in the context of HW 7.5 and contrast the performance of this implementation versus the implementation with no combiners.
#
# Please report the cluster configuration and runtimes in tabular format for both experiments and comment on your findings.
# </pre>
# </div>

# %%
# START STUDENT CODE 7.5.2
#(insert cells as needed)

# END STUDENT CODE 7.5.2

# %% [markdown]
# <h1 style="color:#021353;">HW 7.6: Computational exercise: Largest single-source network distances: OPTIONAL </h1>
# <div style="margin:10px;border-left:5px solid #eee;">
# <pre style="font-family:sans-serif;background-color:transparent">
# Using MRJob, write a code to find the largest graph distance and distance-maximizing nodes from a single-source.
# Test your code first on the toy networks and synonyms network to proof its function.
# </pre>
# </div>

# %%
# START STUDENT CODE 7.6
#(insert cells as needed)

# END STUDENT CODE 7.6

# %% [markdown]
# <h1 style="color:#021353;">HW 7.7: Bellman–Ford: OPTIONAL </h1>
# <div style="margin:10px;border-left:5px solid #eee;">
# <pre style="font-family:sans-serif;background-color:transparent">
# Using MRJob, implement Bellman–Ford algorithm https://en.wikipedia.org/wiki/Bellman%E2%80%93Ford_algorithm. Generate a toy graph with negaitve edges and calculate shortest path from some source to some target within your graph.
# </pre>
# </div>

# %%
# START STUDENT CODE 7.7
#(insert cells as needed)

# END STUDENT CODE 7.7

# %% [markdown]
# ==================END HW 7==================
